# %% [markdown]
# **Problem2**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# **Problem 3**

# %%
my_na_values = ['Unspecified']
data = pd.read_csv("/content/gdrive/My Drive/Colab Notebooks/311-service-requests.csv", na_values=my_na_values)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# **Problem4**

# %%
data.head(10)
# Out:
#    Unique Key  ...                                  Location
# 0    26589651  ...   (40.70827532593202, -73.79160395779721)
# 1    26593698  ...  (40.721040535628305, -73.90945306791765)
# 2    26594139  ...   (40.84332975466513, -73.93914371913482)
# 3    26595721  ...    (40.7780087446372, -73.98021349023975)
# 4    26590930  ...   (40.80769092704951, -73.94738703491433)
# 5    26592370  ...    (40.7499893014072, -73.88198770727831)
# 6    26595682  ...   (40.68153278675525, -73.83173699701601)
# 7    26595195  ...   (40.67181584567338, -73.84309181950769)
# 8    26590540  ...   (40.73991339303542, -74.00079028612932)
# 9    26594392  ...   (40.66820406598287, -73.95064760056546)
#
# [10 rows x 52 columns]

# %% [markdown]
# **Problem5**

# %%
data[data['City'] == 'NEW YORK']['City'].shape
# Out:
# (22664,)

# %% [markdown]
# **Problem6**

# %%
data[data['City'].str.contains('NEW YORK').fillna(False)]['City'].unique()
# Out:
# array(['NEW YORK', 'WEST NEW YORK', 'NEW YORK CITY'], dtype=object)

# %% [markdown]
# **Problem7**

# %%
data_nypd = data[data['Agency'] == 'NYPD']
data_nypd = data_nypd[~data_nypd['Closed Date'].isna()]
data_nypd
# Out:
#         Unique Key  ...                                  Location
# 2         26594139  ...   (40.84332975466513, -73.93914371913482)
# 3         26595721  ...    (40.7780087446372, -73.98021349023975)
# 7         26595195  ...   (40.67181584567338, -73.84309181950769)
# 8         26590540  ...   (40.73991339303542, -74.00079028612932)
# 9         26594392  ...   (40.66820406598287, -73.95064760056546)
# ...            ...  ...                                       ...
# 111061    26426164  ...  (40.762278541098084, -73.92601303458156)
# 111065    26428083  ...  (40.656160351546845, -73.76735262738222)
# 111066    26428987  ...  (40.740295354643706, -73.97695165980414)
# 111067    26426115  ...   (40.64018174662485, -73.95530566958138)
# 111068    26428033  ...  (40.640024057399216, -73.90071711703163)
#
# [15248 rows x 52 columns]

# %% [markdown]
# **Problem8**

# %%
location_cnt = data_nypd['Location Type'].value_counts()

# %% [markdown]
# **Problem9**

# %%
location_cnt.plot.pie(figsize=(10,10), fontsize=10, legend=True)

# %% [markdown]
# **Problem10**

# %%
smalldata = data[['Closed Date', 'Agency', 'Descriptor', 'Location Type']]
smalldata = smalldata.dropna()
smalldata
# Out:
#                    Closed Date  ...        Location Type
# 2       10/31/2013 02:40:32 AM  ...  Club/Bar/Restaurant
# 3       10/31/2013 02:21:48 AM  ...      Street/Sidewalk
# 7       10/31/2013 01:58:49 AM  ...  Club/Bar/Restaurant
# 8       10/31/2013 02:28:04 AM  ...  Club/Bar/Restaurant
# 9       10/31/2013 02:23:51 AM  ...  Club/Bar/Restaurant
# ...                        ...  ...                  ...
# 111064  10/07/2013 04:07:16 PM  ...                 Park
# 111065  10/04/2013 02:13:50 AM  ...      Street/Sidewalk
# 111066  10/04/2013 01:25:01 AM  ...      Street/Sidewalk
# 111067  10/04/2013 04:17:32 AM  ...  Club/Bar/Restaurant
# 111068  10/04/2013 01:20:52 AM  ...      Street/Sidewalk
#
# [38492 rows x 4 columns]

# %% [markdown]
# **Problem11**

# %%
smalldata = smalldata[smalldata['Closed Date'].str.slice(20,22) == 'PM']

c1 = smalldata[smalldata['Closed Date'].str.slice(11,13) == '01']['Agency'].value_counts()
c2 = smalldata[smalldata['Closed Date'].str.slice(11,13) == '03']['Agency'].value_counts()
c3 = smalldata[smalldata['Closed Date'].str.slice(11,13) == '05']['Agency'].value_counts()
c4 = smalldata[smalldata['Closed Date'].str.slice(11,13) == '07']['Agency'].value_counts()

newdata = pd.DataFrame({'01 PM': c1, '03 PM': c2, '05 PM':c3, '07 PM':c4})
newdata = newdata.dropna()
newdata
# Out:
#       01 PM  03 PM  05 PM  07 PM
# DOT   188.0    396   82.0    2.0
# DPR   190.0    122   40.0    5.0
# DSNY   64.0     85   45.0   35.0
# FDNY   38.0     66   58.0   51.0
# HRA    27.0     30   20.0   23.0
# NYPD  521.0    956  448.0  561.0

# %% [markdown]
# **Problem12**

# %%
newdata.sort_values(by='03 PM').plot.area(stacked=True)
